# %%
# Make sure the folder is in sys.path
import sys
sys.path.append(r"C:\Users\It's Blue\SentimentScope")

# Import your sentiment analyzer
import sentiment_analyzer
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\It's
# [nltk_data]     Blue\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Accuracy: 0.8526
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85      4961
#     positive       0.85      0.86      0.85      5039
#
#     accuracy                           0.85     10000
#    macro avg       0.85      0.85      0.85     10000
# weighted avg       0.85      0.85      0.85     10000
#
# Model and vectorizeR saved!
